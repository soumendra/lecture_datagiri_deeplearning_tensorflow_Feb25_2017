# %%
import tensorflow as tf 
from my_layers import cifar_fmp
from fmp_training import is_training 
from fmp_reader import model_train

# %%
summary_dir = "/tmp/tensorflowlogs/cifar100_fmp"

# %%
X = tf.placeholder(tf.float32,[None, 94, 94, 3])
Y = tf.placeholder(tf.float32,[None,1])

# %%
train_dir = ["/Users/PrakashR/Downloads/prakash/experiments/cifar100/cifar-100-binary/train.bin"]
test_dir = ["/Users/PrakashR/Downloads/prakash/experiments/cifar100/cifar-100-binary/test.bin"]

# %%
model = cifar_fmp(X) #pseudo_random = False, overlapping= False

# %%
model
# Out:
# <tf.Tensor 'fc_final/Add:0' shape=(?, 100) dtype=float32>

# %%
accuracy, train_step = is_training(Y,model)

# %%
model_train(X, Y, train_dir, test_dir, train_step, accuracy, batch_size = 32, num_epochs=10, summary_dir = summary_dir)
# Out:
# [queue runners started]
# [Training has initiated]
# ALL Working Fine
